# %% [markdown]
# ### Rolling forecast

# %%
from statsmodels.compat.pandas import deprecate_kwarg
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
# additive decompose a contrived additive time series
from random import randrange
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose 

# the main library has a small set of functionality
from stldecompose import decompose, forecast
from stldecompose.forecast_funcs import (naive,
                                         drift, 
                                         mean, 
                                         seasonal_naive)
# %load_ext autoreload
# %autoreload 2
data = pd.read_csv('/Users/alket/Desktop/dati/new_data_backfill_forwfill.csv', index_col = 0, 
                   header=0, parse_dates=True)
agg_by_cell = data.groupby(by = ['cell_num'])
print(len(agg_by_cell), 'celle')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 221 celle

# %%
serie_dati = agg_by_cell.get_group('490-1264')
#serie_dati = serie_dati.iloc[::4, :]
serie_dati = serie_dati[:800]

# %%
counter = 0
dict2data = {}
error_list = []

print(counter)
counter +=1
dates4dec = []
cell_values = []

for index, row in serie_dati.iterrows():
    
        date = row['date']
        h = str(row['hours'])
   
        h = h.split('.')
    
        if len(h[0])<2:
            h = h[1]+h[0]
        else: 
            h = h[0]
   
        minutes = str(row['minutes'])
        m = ''
        minutes = minutes.split('.')
        if len(minutes[0])<2: 
            m = minutes[0] +'0'
        else: 
            m = minutes[0]
        #print(date, h, m)
        data_f = date+' '+h+':'+m+':'+'00'
        #print(data_f)
        cell_values.append(row['nr_people'])
        dates4dec.append(data_f)
# Out:
# 0

# %%
dict_i = {'ds': dates4dec, 'y':cell_values}
data4deco = pd.DataFrame(dict_i, index=None, columns=None)  
data4deco.head()

data4deco['ds'] = pd.to_datetime(data4deco['ds'])
data4deco = data4deco.set_index('ds')
data4deco.head()
# Out:
#                         y
# ds
# 2017-04-16 00:00:00  28.0
# 2017-04-16 00:15:00  28.0
# 2017-04-16 00:30:00  28.0
# 2017-04-16 00:45:00  27.0
# 2017-04-16 01:00:00  27.0

# %%
decomp = decompose(data4deco['y'], period=96)

with plt.rc_context():
     plt.rc("figure", figsize=(20,8))
     decomp.plot()
     plt.show()

# %%
trend = decomp.trend.values
#print(trend.head(2))
seasonal = decomp.seasonal.values
#print(seasonal.head(2))
residual = decomp.resid.values
#print(residual.head(2))

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequence)):
         # find the end of this pattern
         end_ix = i + n_steps_in
         out_end_ix = end_ix + n_steps_out
         # check if we are beyond the sequence
         if out_end_ix > len(sequence):
             break
         # gather input and output parts of the pattern
         seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
         X.append(seq_x)
         y.append(seq_y)
    return np.array(X), np.array(y)

# %%
def get_forcast_per_component(series, st_in, st_out):
    
    # split into samples
    X, y = split_sequence(series, st_in, st_out)

    # predict 
    predicted = []
    for i in range(len(X)):
        print('------------->>>', X[i])
        model = ARIMA(X[i], order=(4,1,0)) 
        model_fit = model.fit(disp=0)
        output = model_fit.forecast(steps = st_out)
        yhat = output[0]
        print('i ', yhat)
    
        #predicted.append(np.rint(yhat[0]))   
        predicted.append(np.around(yhat, decimals=1)) 
    predicted = np.array(predicted)
    return predicted

# %%
n_steps_in, n_steps_out = 24, 20


forcasted_trend = get_forcast_per_component(trend, n_steps_in, n_steps_out)
print('finished trend')
forcasted_residual = get_forcast_per_component(residual, n_steps_in, n_steps_out)
print('finished residual')
forcasted_season = get_forcast_per_component(seasonal, n_steps_in, n_steps_out)
# Out:
# ------------->>> [22.49469642 22.53063403 22.56657164 22.60250925 22.63844685 22.67438446
#  22.71032207 22.74625968 22.78219728 22.81821243 22.85422758 22.89024272
#  22.92625787 22.96227302 22.99828816 23.03430331 23.07031846 23.10640455
# ------------->>> [22.71032207 22.74625968 22.78219728 22.81821243 22.85422758 22.89024272
#  22.92625787 22.96227302 22.99828816 23.03430331 23.07031846 23.10640455
#  23.14249063 23.17857672 23.21466281 23.2507489  23.28683499 23.32292108
#  23.35900717 23.39516092 23.43131468 23.46746844 23.50362219 23.53977595]
# i  [23.57592431 23.61206735 23.64820528 23.68433827 23.72046657 23.75659046
#  23.79271019 23.828826   23.86493811 23.90104674 23.93715209 23.97325436
#  24.00935371 24.04545032 24.08154434 24.11763593 24.15372523 24.18981237
#  24.22589747 24.26198066]
# ------------->>> [22.74625968 22.78219728 22.81821243 22.85422758 22.89024272 22.92625787
#  22.96227302 22.99828816 23.03430331 23.07031846 23.10640455 23.14249063
#  23.17857672 23.21466281 23.2507489  23.28683499 23.32292108 23.35900717
#  23.39516092 23.43131468 23.46746844 23.50362219 23.53977595 23.5759297 ]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-216-255ebdc6a31c> in <module>
#       2
#       3
# ----> 4 forcasted_trend = get_forcast_per_component(trend, n_steps_in, n_steps_out)
#       5 print('finished trend')
#       6 forcasted_residual = get_forcast_per_component(residual, n_steps_in, n_steps_out)
#
# <ipython-input-215-8fa5ca721ffb> in get_forcast_per_component(series, st_in, st_out)
#       9         print('------------->>>', X[i])
#      10         model = ARIMA(X[i], order=(4,1,0))
# ---> 11         model_fit = model.fit(disp=0)
#      12         output = model_fit.forecast(steps = st_out)
#      13         yhat = output[0]
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1147                                            method, transparams, solver,
#    1148                                            maxiter, full_output, disp,
# -> 1149                                            callback, start_ar_lags, **kwargs)
#    1150         normalized_cov_params = None  # TODO: fix this?
#    1151         arima_fit = ARIMAResults(self, mlefit._results.params,
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     949                                        maxiter=maxiter,
#     950                                        full_output=full_output, disp=disp,
# --> 951                                        callback=callback, **kwargs)
#     952         params = mlefit.params
#     953
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     468                                                        callback=callback,
#     469                                                        retall=retall,
# --> 470                                                        full_output=full_output)
#     471
#     472         # NOTE: this is for fit_regularized and should be generalized
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     217                             disp=disp, maxiter=maxiter, callback=callback,
#     218                             retall=retall, full_output=full_output,
# --> 219                             hess=hessian)
#     220
#     221         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     437                                      callback=callback, args=fargs,
#     438                                      bounds=bounds, disp=disp,
# --> 439                                      **extra_kwargs)
#     440
#     441     if full_output:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     279         def func_and_grad(x):
#     280             f = fun(x, *args)
# --> 281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#     283     else:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     694         ei[k] = 1.0
#     695         d = epsilon * ei
# --> 696         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     697         ei[k] = 0.0
#     698     return grad
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in f(params, *args)
#     442
#     443         def f(params, *args):
# --> 444             return -self.loglike(params, *args) / nobs
#     445
#     446         if method == 'newton':
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in loglike(self, params, set_sigma2)
#     770         method = self.method
#     771         if method in ['mle', 'css-mle']:
# --> 772             return self.loglike_kalman(params, set_sigma2)
#     773         elif method == 'css':
#     774             return self.loglike_css(params, set_sigma2)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py in loglike_kalman(self, params, set_sigma2)
#     780         Compute exact loglikelihood for ARMA(p,q) model by the Kalman Filter.
#     781         """
# --> 782         return KalmanFilter.loglike(params, self, set_sigma2)
#     783
#     784     def loglike_css(self, params, set_sigma2=True):
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py in loglike(cls, params, arma_model, set_sigma2)
#     219             loglike, sigma2 = kalman_loglike.kalman_loglike_double(
#     220                 y, k, k_ar, k_ma, k_lags, int(nobs),
# --> 221                 Z_mat, R_mat, T_mat)
#     222         elif np.issubdtype(paramsdtype, np.complex128):
#     223             loglike, sigma2 = kalman_loglike.kalman_loglike_complex(
#
# statsmodels/tsa/kalmanf/kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_loglike_double()
#
# statsmodels/tsa/kalmanf/kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_filter_double()
#
# <__array_function__ internals> in zeros_like(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in zeros_like(a, dtype, order, subok, shape)
#     157
#     158     """
# --> 159     res = empty_like(a, dtype=dtype, order=order, subok=subok, shape=shape)
#     160     # needed instead of a 0 to get same result as zeros for for string dtypes
#     161     z = zeros(1, dtype=res.dtype)
#
# <__array_function__ internals> in empty_like(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
forcasted_season
# Out:
# array([[ -7.4,  -7.1,  -6.8, ...,  -7. ,  -7.2,  -7.3],
#        [ -6.9,  -6.6,  -6.3, ...,  -5.8,  -5.9,  -6.1],
#        [ -7.1,  -7.1,  -7.2, ..., -10. , -10.2, -10.5],
#        ...,
#        [ -5.3,  -5.6,  -6. , ..., -11.9, -12.3, -12.7],
#        [ -6. ,  -6.4,  -6.8, ..., -12.9, -13.3, -13.7],
#        [ -6.8,  -7.4,  -7.9, ..., -14.9, -15.4, -15.9]])

# %%
final_prediction = forcasted_trend + forcasted_residual + forcasted_season

# %%
X, y = split_sequence(serie_dati['nr_people'].values, n_steps_in, n_steps_out)

# %%
print(final_prediction.shape)
expected = y
print(expected.shape)
# Out:
# (757, 20)
# (757, 20)

# %%
difference = abs(expected - final_prediction)

# %%
plt.figure(figsize = (15,9))
plt.boxplot(difference, vert= False);
plt.show()
